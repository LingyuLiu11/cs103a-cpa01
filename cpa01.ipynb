# %% [markdown]
# # CPA01
# The data is about Electronic card transactions: February 2022
#
#
# URL: https://www.stats.govt.nz/assets/Uploads/Electronic-card-transactions/Electronic-card-transactions-February-2022/Download-data/electronic-card-transactions-february-2022-csv.zip
#
# Interesting questions: Which is the most popular status and which has the highest average value.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data/data.csv')

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 18451       ECTQ.S4AXP  2020.12        38.6        NaN      F  Percent
# 18452       ECTQ.S4AXP  2021.03        38.4        NaN      F  Percent
# 18453       ECTQ.S4AXP  2021.06        38.0        NaN      F  Percent
# 18454       ECTQ.S4AXP  2021.09        34.8        NaN      F  Percent
# 18455       ECTQ.S4AXP  2021.12        33.1        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
df.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  18456.000000  1.688700e+04  18456.000000             0.0
# mean    2011.315068  1.543755e+07      4.207737             NaN
# std        6.008214  8.419977e+07      2.746230             NaN
# min     2000.010000 -5.130000e+01      0.000000             NaN
# 25%     2006.090000  1.764000e+02      0.000000             NaN
# 50%     2011.090000  1.172900e+03      6.000000             NaN
# 75%     2016.120000  4.225750e+03      6.000000             NaN
# max     2022.020000  1.874441e+09      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df2 = df[df['STATUS']=='F']
df2
df2.plot(x='Period', y='Data_value')
plt.xlabel('Period')
plt.ylabel('Data_value')
plt.title('value in years of status F')
plt.grid()
plt.legend()

# %%
table = pd.pivot_table(df, values='Period', index=['Data_value'], columns = ['STATUS'])
table
# Out:
# STATUS               F   P        R
# Data_value
# -5.130000e+01  2020.04 NaN      NaN
# -4.830000e+01      NaN NaN  2020.04
# -4.750000e+01  2020.04 NaN      NaN
# -4.740000e+01      NaN NaN  2020.04
# -4.520000e+01      NaN NaN  2020.04
# ...                ...  ..      ...
#  1.627460e+09  2017.03 NaN      NaN
#  1.732692e+09  2021.03 NaN      NaN
#  1.754266e+09  2018.03 NaN      NaN
#  1.835450e+09  2019.03 NaN      NaN
#  1.874441e+09  2020.03 NaN      NaN
#
# [12441 rows x 3 columns]

# %%
table[['F', 'P', 'R']].plot()
# Out:
# <AxesSubplot:xlabel='Data_value'>

# %%
df3 = df.groupby(['STATUS'])

df3.describe()
# Out:
#         Period                                                                 \
#          count         mean       std      min        25%      50%        75%
# STATUS
# C       1567.0  2006.657920  8.916349  2000.01  2001.0100  2002.01  2020.0550
# F       8337.0  2011.934480  5.566133  2001.03  2007.0700  2012.03  2017.0300
# P         14.0  2020.791429  0.451644  2020.09  2020.3475  2021.03  2021.0825
# R       8538.0  2011.549437  5.351886  2002.10  2007.0500  2011.12  2016.0775
#
#                 Data_value                ... Series_title_4      \
#             max      count          mean  ...            75% max
# STATUS                                    ...
# C       2022.02        0.0           NaN  ...            NaN NaN
# F       2022.02     8335.0  3.082819e+07  ...            NaN NaN
# P       2021.12       14.0  3.313507e+03  ...            NaN NaN
# R       2022.01     8538.0  4.381428e+05  ...            NaN NaN
#
#        Series_title_5
# ...

# %% [markdown]
# ####
# The data shows that The mean value of ststus F is larger than others. Also F and R are the two most popular status.
